# %%
import fnmatch
import os
import pandas as pd
from os.path import isfile, join
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# plot settings:

# %%
mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 75

mpl.rcParams['font.family'] = 'serif'

# %% [markdown]
# # Plotting Data
#
# In this notebook I will plot the data of the vertex fraction vs. magnetic field of the hysteresis loops at different mT/s rates.

# %%
Data_path = "/home/carolina/Dropbox/BidisperseColloidalIce_PROJECT"

# %%
inc = []
dec = []
for file in os.listdir(Data_path):
    if fnmatch.fnmatch(file, 'Bajada*.dat'):
        print(file)
        dec.append(pd.read_csv(join(Data_path,file), sep = "\t", index_col = [0,1])) 
    if fnmatch.fnmatch(file, 'Subida*.dat'):
        inc.append(pd.read_csv(join(Data_path,file), sep = "\t", index_col = [0,1])) 
field_max = 200
keys = [21091,3671,4042,6784,8169,4496,3362,13810,10265,5066]
# Out:
# Bajada21091.dat
# Bajada3671.dat
# Bajada4042.dat
# Bajada6784.dat
# Bajada8169.dat
# Bajada4496.dat
# Bajada3362.dat
# Bajada13810.dat
# Bajada10265.dat
# Bajada5066.dat

# %%
keys[:] = [round(field_max/x,4) for x in keys]

# %%
inc = pd.concat(inc, keys = keys)
dec = pd.concat(dec, keys = keys)

# %%
dec.index.names = ['change_m_time', 'field', 'type']
inc.index.names = ['change_m_time', 'field', 'type']

# %%
dec
# Out:
#                                      mean       err
# change_m_time field      type
# 0.0095        0.000000   Type 3       NaN       NaN
#               4.081633   Type 3  0.410867  0.020867
#               8.163265   Type 3  0.417985  0.019923
#               12.244898  Type 3  0.420408  0.055204
#               16.326531  Type 3  0.371505  0.050179
# ...                                   ...       ...
# 0.0595        183.673469 Type 3  0.237024  0.004543
#               187.755102 Type 3  0.243095  0.009282
#               191.836735 Type 3  0.235595  0.012276
#               195.918367 Type 3  0.229048  0.010064
#               200.000000 Type 3  0.217500  0.007638
#
# [500 rows x 2 columns]

# %% [markdown]
# Now, I will filter only the data of the type 3 vertices.

# %%
dec = dec[np.in1d(dec.index.get_level_values(2), ['Type 3'])]
inc = inc[np.in1d(inc.index.get_level_values(2), ['Type 3'])]

# %%
dec = dec.sort_index(0)
inc = inc.sort_index(0)

# %%
fig, ax = plt.subplots(1,2, figsize = (20,10), sharey=True)
cmap = sns.color_palette("viridis", n_colors=10)


dec_data = dec.groupby('change_m_time')
inc_data = inc.groupby('change_m_time')

for i, (n, gr) in enumerate(inc_data):
    ax[0].errorbar(gr.index.get_level_values("field"), gr["mean"],color=cmap[i],label = n)

for i_dec, (n_dec, gr_dec) in enumerate(dec_data):
    ax[1].errorbar(gr_dec.index.get_level_values("field"), gr_dec["mean"], color=cmap[i_dec],label = n_dec)

ax[0].tick_params(axis='y', labelsize=30)
ax[0].tick_params(axis='x', labelsize=30) 
ax[1].tick_params(axis='y', labelsize=30)
ax[1].tick_params(axis='x', labelsize=30)      
ax[1].set_xlabel('B (mT)', size = 30)
ax[0].set_xlabel('B (mT)', size = 30)
ax[0].set_ylabel('Vertex population', size = 30)

plt.legend(bbox_to_anchor=(1.1, 0.9), title = 'mT/s',fontsize = 30, title_fontsize = 30)

plt.savefig('BidisperseIce_hysteresis_loop_type_diffrate', bbox_inches='tight')
