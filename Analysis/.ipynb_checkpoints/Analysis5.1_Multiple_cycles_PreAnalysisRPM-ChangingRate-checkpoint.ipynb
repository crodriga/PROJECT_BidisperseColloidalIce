# %% [markdown]
# # Computing the Spin Overlap Patameter

# %% [markdown]
# In this script, I will do:
#
#     1. Check if the simulation worked fine and do what I expect.
#
#         - Plotting the muz vs. time.
#         - Observe the behaviour
#
#     2. Compute the Spin Overlap Parameter with the obtained data.

# %%
import os 
import sys

sys.path.insert(0, 'icenumerics/')

import icenumerics as ice
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd

ureg = ice.ureg
idx = pd.IndexSlice

import warnings
warnings.filterwarnings("error")


# %reload_ext autoreload
# %autoreload 2

# %%
import magcolloids as mgc

# %%
mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 100

mpl.rcParams['font.family'] = 'serif'

# %% [markdown]
# Importing the data

# %%
k = 9

# %%
load_obj = mgc.trj_lazyread(r"/home/carolina/lammps_script-7/test_Hi_BidisperseColloidalIce_RPM_l22_exp"+str(k)+".lammpstrj", output = ["x","y","z","mux","muy","muz"])

# %%
bnd = load_obj.get_bounds()
trj = load_obj.read_trj()

# %%
trj
# Out:
#               type      x      y    z           mux        muy  muz
# frame   id
# 0       1        1    5.0    0.0  0.0  0.000000e+00   0.000000  0.0
#         2        1   38.0    0.0  0.0  0.000000e+00   0.000000  0.0
#         3        1   71.0    0.0  0.0  0.000000e+00   0.000000  0.0
#         4        1  104.0    0.0  0.0  0.000000e+00   0.000000  0.0
#         5        1  137.0    0.0  0.0  0.000000e+00   0.000000  0.0
# ...            ...    ...    ...  ...           ...        ...  ...
# 1828300 1932     4  561.0  709.5  0.0  1.858760e-15  30.355801  0.0
#         1933     4  594.0  709.5  0.0  1.858760e-15  30.355801  0.0
#         1934     4  627.0  709.5  0.0 -1.858760e-15 -30.355801 -0.0
#         1935     4  660.0  709.5  0.0 -1.858760e-15 -30.355801 -0.0
#         1936     4  693.0  709.5  0.0 -1.858760e-15 -30.355801 -0.0
#
# [35397824 rows x 7 columns]

# %% [markdown]
# ## 1. Checking

# %% [markdown]
# ### 1.1 Checking magnetic field applyed

# %% [markdown]
# Filter the particles dataframes

# %% [markdown]
# In the following cell I will check which type of particle is the one with higher susceptibility and which one has the lower susceptibility. This way I will combine the particle with the corresponding trap.

# %%
a = trj.loc[[1828300]]
# Higher susceptibility
b = a.loc[(a['muz'] > 0.0003), 'type'].unique()
# Lower susceptibility
c = a.loc[((a['muz'] > 0.00005) & (a['muz'] < 0.0003)), 'type'].unique()

# %%
part1 = trj.loc[trj['type'] == b[0]]
part2 = trj.loc[trj['type'] == c[0]]

# %%
plt.plot(part1.index.get_level_values('frame'), part1['muz'], 'o', markersize = 3, label = 'particle 1')
plt.plot(part2.index.get_level_values('frame'), part2['muz'], 'o', markersize = 3, label = 'particle 2')

plt.legend(loc = 'center')
plt.xlabel('time (s)', size = 12)
plt.ylabel('magnetic moment (lammps units)', size = 12)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %%
B_max = 130
B_min = 100
slope = 0.035
tim = []
t = [round(B_max/slope)]

def time(n):
    for i in range(1,n):
        t.append(round(((B_max-B_min)/slope+t[i-1])))
    for i in range(len(t)):
        tim.append(t[i]*100)
    return tim


t = time(18)
t
# Out:
# [371400,
#  457100,
#  542800,
#  628500,
#  714200,
#  799900,
#  885600,
#  971300,
#  1057000,
#  1142700,
#  1228400,
#  1314100,
#  1399800,
#  1485500,
#  1571200,
#  1656900,
#  1742600,
#  1828300]

# %% [markdown]
# The behaviuor is what I expected, so the simulations worked fine. Now I can pass to point 2.

# %% [markdown]
# ### 1.2 Checking particles trajectories

# %%
# for i, trj_i in trj.groupby("id"):
#     plt.plot(trj_i.x, trj_i.y)

# %% [markdown]
# ### 1.3 Checking the particles positions after each loop

# %% [markdown]
# The following loop will separate the particles data at the end of the cycle.

# %%
part = trj.loc[trj['type'] < 3]

particles = []

for i in range(len(t)):
    if i % 2 == 0: # if i is even 
 #       particles.append(part.loc[[t[i]], ['x','y']])
        pass
    else:
        particles.append(part.loc[[t[i]], ['x','y']])

part = pd.concat(particles, axis =0)
part
# Out:
#                       x           y
# frame   id
# 457100  1     15.660700   -0.032600
#         2     45.118099   -0.152190
#         3     83.485100   -0.104014
#         4    113.166000   -0.063062
#         5    152.014008   -0.182385
# ...                 ...         ...
# 1828300 964  561.007996  708.325989
#         965  593.929016   -1.185560
#         966  627.025024  698.638977
#         967  660.117004  716.119019
#         968  692.961975  709.572998
#
# [8712 rows x 2 columns]

# %% [markdown]
# Adding the trap information

# %%
# short trap
d = a.loc[(abs(a['mux']) > 10), 'type'].unique()
# long trap
e = a.loc[(abs(a['muy']) > 10), 'type'].unique()

# %%
e
# Out:
# array([4])

# %%
trap_long = trj.loc[trj['type'] == e[0]] # Are the 30 um traps, those that contains particle 2
trap_short = trj.loc[trj['type'] == d[0]] # Are the 23 um traps, those that contains particle 1

# %%
trap_short
# Out:
#               type      x      y    z   mux  muy  muz
# frame   id
# 0       969      3   16.5    0.0  0.0 -23.0 -0.0 -0.0
#         970      3   49.5    0.0  0.0 -23.0 -0.0 -0.0
#         971      3   82.5    0.0  0.0 -23.0 -0.0 -0.0
#         972      3  115.5    0.0  0.0 -23.0 -0.0 -0.0
#         973      3  148.5    0.0  0.0 -23.0 -0.0 -0.0
# ...            ...    ...    ...  ...   ...  ...  ...
# 1828300 1448     3  577.5  693.0  0.0 -23.0 -0.0 -0.0
#         1449     3  610.5  693.0  0.0  23.0  0.0  0.0
#         1450     3  643.5  693.0  0.0 -23.0 -0.0 -0.0
#         1451     3  676.5  693.0  0.0  23.0  0.0  0.0
#         1452     3  709.5  693.0  0.0 -23.0 -0.0 -0.0
#
# [8849456 rows x 7 columns]

# %%
def reordering_id(df):
    df = df.reset_index()
    df["id"] = df["id"]-min(df["id"])
    df = df.set_index(['frame', 'id'])
    del df['type']
    return df

# %%
t_short = reordering_id(trap_short)
t_long = reordering_id(trap_long)

# %%
t_short
# Out:
#                  x      y    z   mux  muy  muz
# frame   id
# 0       0     16.5    0.0  0.0 -23.0 -0.0 -0.0
#         1     49.5    0.0  0.0 -23.0 -0.0 -0.0
#         2     82.5    0.0  0.0 -23.0 -0.0 -0.0
#         3    115.5    0.0  0.0 -23.0 -0.0 -0.0
#         4    148.5    0.0  0.0 -23.0 -0.0 -0.0
# ...            ...    ...  ...   ...  ...  ...
# 1828300 479  577.5  693.0  0.0 -23.0 -0.0 -0.0
#         480  610.5  693.0  0.0  23.0  0.0  0.0
#         481  643.5  693.0  0.0 -23.0 -0.0 -0.0
#         482  676.5  693.0  0.0  23.0  0.0  0.0
#         483  709.5  693.0  0.0 -23.0 -0.0 -0.0
#
# [8849456 rows x 6 columns]

# %%
short = trap_short.loc[trap_short.index.get_level_values('frame') == 0]
long = trap_long.loc[trap_long.index.get_level_values('frame') == 0]

# %%
from matplotlib.patches import Circle,Rectangle
from matplotlib.collections import PatchCollection

# %%
short
# Out:
#             type      x      y    z   mux  muy  muz
# frame id
# 0     969      3   16.5    0.0  0.0 -23.0 -0.0 -0.0
#       970      3   49.5    0.0  0.0 -23.0 -0.0 -0.0
#       971      3   82.5    0.0  0.0 -23.0 -0.0 -0.0
#       972      3  115.5    0.0  0.0 -23.0 -0.0 -0.0
#       973      3  148.5    0.0  0.0 -23.0 -0.0 -0.0
# ...          ...    ...    ...  ...   ...  ...  ...
#       1448     3  577.5  693.0  0.0 -23.0 -0.0 -0.0
#       1449     3  610.5  693.0  0.0  23.0  0.0  0.0
#       1450     3  643.5  693.0  0.0 -23.0 -0.0 -0.0
#       1451     3  676.5  693.0  0.0  23.0  0.0  0.0
#       1452     3  709.5  693.0  0.0 -23.0 -0.0 -0.0
#
# [484 rows x 7 columns]

# %%
patches_l = []
patches_s = []
for index, row in long.iterrows():
    
    c_s = Circle((row['x'],row['y']+15.1779), radius=0.35, color = 'gray', alpha = 0.5)
    c_e = Circle((row['x'],row['y']-15.1779), radius=0.35, color = 'gray', alpha = 0.5)
    r = Rectangle((row['x']-0.35,row['y']-15.1779), width = 0.7 , height = 30.3558, angle=0)
    patches_l.extend((c_s,c_e,r))

for index, row in short.iterrows():   
    
    cs_s = Circle((row['x']+11.5,row['y']), radius=0.35, color = 'gray', alpha = 0.5)
    cs_e = Circle((row['x']-11.5,row['y']), radius=0.35, color = 'gray', alpha = 0.5)
    rs = Rectangle((row['x']-11.5,row['y']+0.35), width = 0.7 , height = 23, angle=-90)
    patches_s.extend((cs_s,cs_e,rs))

# %%
fig, ax = plt.subplots()
patches = patches_l + patches_s
p = PatchCollection(patches, alpha=1, color = 'gray')
ax.add_collection(p)

for i, trj_i in part.groupby("frame"):

    plt.plot(trj_i.x, trj_i.y, 'o', label = str(i)+' s')
    plt.axis('equal')
plt.legend( bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlim(0,250)
plt.ylim(50,100)
plt.savefig('Snapshot_system_after_cycles_at_100mT.png', bbox_inches='tight')

# %% [markdown]
# ## 2. Spin Overlap Parameter

# %% [markdown]
# ### Attention! There is something weird

# %%
trap = trj.loc[trj['type'] > 2]
trap
# Out:
#               type      x      y    z           mux        muy  muz
# frame   id
# 0       969      3   16.5    0.0  0.0 -2.300000e+01  -0.000000 -0.0
#         970      3   49.5    0.0  0.0 -2.300000e+01  -0.000000 -0.0
#         971      3   82.5    0.0  0.0 -2.300000e+01  -0.000000 -0.0
#         972      3  115.5    0.0  0.0 -2.300000e+01  -0.000000 -0.0
#         973      3  148.5    0.0  0.0 -2.300000e+01  -0.000000 -0.0
# ...            ...    ...    ...  ...           ...        ...  ...
# 1828300 1932     4  561.0  709.5  0.0  1.858760e-15  30.355801  0.0
#         1933     4  594.0  709.5  0.0  1.858760e-15  30.355801  0.0
#         1934     4  627.0  709.5  0.0 -1.858760e-15 -30.355801 -0.0
#         1935     4  660.0  709.5  0.0 -1.858760e-15 -30.355801 -0.0
#         1936     4  693.0  709.5  0.0 -1.858760e-15 -30.355801 -0.0
#
# [17698912 rows x 7 columns]

# %% [markdown]
# I think that there is something wrong in the assignation of the 'mux' and 'muy' value.

# %%
df = trap.groupby(['id'])
for i, (n, gr) in enumerate(df):
    plt.plot(gr['muy'].values, '-', )
#     plt.plot(gr.mux)

# %% [markdown]
# From this plot seems that spins are not correcly defined. The spins does not flip during the simulation eventhough in the particles trajectories we observe some flips.

# %% [markdown]
# ### Trying to solve this:

# %% [markdown]
# I will try to extract with the information that I have the mux and muy value, as the following image shown, there is spin flips during the experiments.

# %%
t_short = reordering_id(trap_short)
t_long = reordering_id(trap_long)
p1 = reordering_id(part1)
p2 = reordering_id(part2)

# %%
t_short
# Out:
#                  x      y    z   mux  muy  muz
# frame   id
# 0       0     16.5    0.0  0.0 -23.0 -0.0 -0.0
#         1     49.5    0.0  0.0 -23.0 -0.0 -0.0
#         2     82.5    0.0  0.0 -23.0 -0.0 -0.0
#         3    115.5    0.0  0.0 -23.0 -0.0 -0.0
#         4    148.5    0.0  0.0 -23.0 -0.0 -0.0
# ...            ...    ...  ...   ...  ...  ...
# 1828300 479  577.5  693.0  0.0 -23.0 -0.0 -0.0
#         480  610.5  693.0  0.0  23.0  0.0  0.0
#         481  643.5  693.0  0.0 -23.0 -0.0 -0.0
#         482  676.5  693.0  0.0  23.0  0.0  0.0
#         483  709.5  693.0  0.0 -23.0 -0.0 -0.0
#
# [8849456 rows x 6 columns]

# %%
p1
# Out:
#                       x           y    z  mux  muy       muz
# frame   id
# 0       0      5.000000    0.000000  0.0  0.0  0.0  0.000000
#         1     38.000000    0.000000  0.0  0.0  0.0  0.000000
#         2     71.000000    0.000000  0.0  0.0  0.0  0.000000
#         3    104.000000    0.000000  0.0  0.0  0.0  0.000000
#         4    137.000000    0.000000  0.0  0.0  0.0  0.000000
# ...                 ...         ...  ...  ...  ...       ...
# 1828300 479  579.280029  693.101013  0.0  0.0  0.0  0.000557
#         480  608.538025  693.111023  0.0  0.0  0.0  0.000557
#         481  644.872986  693.098022  0.0  0.0  0.0  0.000557
#         482  672.890015  692.864990  0.0  0.0  0.0  0.000557
#         483  706.312012  692.879028  0.0  0.0  0.0  0.000557
#
# [8849456 rows x 6 columns]

# %%
def filter_RPM_data(df,t):
    df_def = []
        
    for i in range(len(t)):
        if i % 2 == 0: # if i is even 
            pass
#            df_def.append(df.loc[[t[i]]])
        else:
            df_def.append(df.loc[[t[i]]])

    df_f = pd.concat(df_def, axis =0)
    return df_f

# %%
t_short = filter_RPM_data(t_short,t)
t_long = filter_RPM_data(t_long,t)
p1 = filter_RPM_data(p1,t)
p2 = filter_RPM_data(p2,t)

# %%
# # plt.plot(p1.x, p1.y , 'o', c ='blue', alpha = 0.1)
# # plt.plot(p2.x, p2.y , 'o', c ='blue', alpha = 0.1)
# # plt.plot(t_long.x, t_long.y , 'o', color = 'gray')
# plt.plot(t_short.x, t_short.y , 'o', color = 'gray', markersize = 10)
# plt.plot(t_shor.x, t_shor.y , 'o', color = 'blue', markersize = 5)
# # plt.plot(p1.x, p2.y , 'o', color = 'orange', markersize = 1)
# plt.axis('equal')

# %%
t_s = t_short.rename(columns={"x": "tx", "y": "ty", "z": "tz", "mux": "tmux", "muy": "tmuy", "muz" : "tmuz"})
t_l = t_long.rename(columns={"x": "tx", "y": "ty", "z": "tz", "mux": "tmux", "muy": "tmuy", "muz" : "tmuz"})
t_s
# Out:
#                 tx     ty   tz  tmux  tmuy  tmuz
# frame   id
# 457100  0     16.5    0.0  0.0 -23.0  -0.0  -0.0
#         1     49.5    0.0  0.0 -23.0  -0.0  -0.0
#         2     82.5    0.0  0.0 -23.0  -0.0  -0.0
#         3    115.5    0.0  0.0 -23.0  -0.0  -0.0
#         4    148.5    0.0  0.0 -23.0  -0.0  -0.0
# ...            ...    ...  ...   ...   ...   ...
# 1828300 479  577.5  693.0  0.0 -23.0  -0.0  -0.0
#         480  610.5  693.0  0.0  23.0   0.0   0.0
#         481  643.5  693.0  0.0 -23.0  -0.0  -0.0
#         482  676.5  693.0  0.0  23.0   0.0   0.0
#         483  709.5  693.0  0.0 -23.0  -0.0  -0.0
#
# [4356 rows x 6 columns]

# %%
a  = pd.concat((p1,t_s), axis = 1)
b  = pd.concat((p2,t_l), axis = 1)

# %%
b.loc[(1828300),:].tail(50)
# Out:
#               x           y    z  mux  muy       muz            tx     ty  \
# id
# 434  527.994995  656.507996  0.0  0.0  0.0  0.000075  5.280000e+02  643.5
# 435  561.000977  633.018005  0.0  0.0  0.0  0.000075  5.610000e+02  643.5
# 436  594.122009  658.218018  0.0  0.0  0.0  0.000075  5.940000e+02  643.5
# 437  627.015015  635.841003  0.0  0.0  0.0  0.000075  6.270000e+02  643.5
# 438  660.054993  645.452026  0.0  0.0  0.0  0.000075  6.600000e+02  643.5
# 439  693.142029  642.106995  0.0  0.0  0.0  0.000075  6.930000e+02  643.5
# 440    0.002142  691.606995  0.0  0.0  0.0  0.000075  1.010330e-15  676.5
# 441   32.910301  661.148987  0.0  0.0  0.0  0.000075  3.300000e+01  676.5
# 442   65.910004  677.276978  0.0  0.0  0.0  0.000075  6.600000e+01  676.5
# 443   98.965103  691.833984  0.0  0.0  0.0  0.000075  9.900000e+01  676.5
# 444  132.093002  675.783020  0.0  0.0  0.0  0.000075  1.320000e+02  676.5
# 445  164.811996  675.703979  0.0  0.0  0.0  0.000075  1.650000e+02  676.5
# 446  197.925003  674.143982  0.0  0.0  0.0  0.000075  1.980000e+02  676.5
# 447  231.203995  673.104004  0.0  0.0  0.0  0.000075  2.310000e+02  676.5
# 448  263.980011  676.536011  0.0  0.0  0.0  0.000075  2.640000e+02  676.5
# 449  296.886993  671.416992  0.0  0.0  0.0  0.000075  2.970000e+02  676.5
# 450  330.105011  680.046997  0.0  0.0  0.0  0.000075  3.300000e+02  676.5
# 451  362.910004  663.487000  0.0  0.0  0.0  0.000075  3.630000e+02  676.5
# 452  395.919006  689.280029  0.0  0.0  0.0  0.000075  3.960000e+02  676.5
# 453  428.990997  676.601990  0.0  0.0  0.0  0.000075  4.290000e+02  676.5
# 444  0.0 -1.858760e-15 -30.355801  -0.0
# 445  0.0  1.858760e-15  30.355801   0.0
# 446  0.0  1.858760e-15  30.355801   0.0
# 447  0.0  1.858760e-15  30.355801   0.0
# 448  0.0  1.858760e-15  30.355801   0.0
# 449  0.0 -1.858760e-15 -30.355801  -0.0
# 450  0.0 -1.858760e-15 -30.355801  -0.0
# 451  0.0  1.858760e-15  30.355801   0.0
# 452  0.0  1.858760e-15  30.355801   0.0
# 453  0.0 -1.858760e-15 -30.355801  -0.0
# 454  0.0  1.858760e-15  30.355801   0.0
# 455  0.0 -1.858760e-15 -30.355801  -0.0
# 456  0.0  1.858760e-15  30.355801   0.0
# 457  0.0  1.858760e-15  30.355801   0.0
# 458  0.0  1.858760e-15  30.355801   0.0
# 459  0.0  1.858760e-15  30.355801   0.0
# 460  0.0 -1.858760e-15 -30.355801  -0.0
# 461  0.0  1.858760e-15  30.355801   0.0
# 462  0.0  1.858760e-15  30.355801   0.0
# 463  0.0  1.858760e-15  30.355801   0.0
# 464  0.0  1.858760e-15  30.355801   0.0
# 465  0.0 -1.858760e-15 -30.355801  -0.0
# 466  0.0  1.858760e-15  30.355801   0.0
# 467  0.0  1.858760e-15  30.355801   0.0
# 468  0.0  1.858760e-15  30.355801   0.0
# 469  0.0 -1.858760e-15 -30.355801  -0.0
# 470  0.0 -1.858760e-15 -30.355801  -0.0
# 471  0.0 -1.858760e-15 -30.355801  -0.0
# 472  0.0  1.858760e-15  30.355801   0.0
# 473  0.0  1.858760e-15  30.355801   0.0
# 474  0.0  1.858760e-15  30.355801   0.0
# 475  0.0 -1.858760e-15 -30.355801  -0.0
# 476  0.0  1.858760e-15  30.355801   0.0
# 477  0.0 -1.858760e-15 -30.355801  -0.0
# 478  0.0  1.858760e-15  30.355801   0.0
# 479  0.0  1.858760e-15  30.355801   0.0
# 480  0.0  1.858760e-15  30.355801   0.0
# 481  0.0 -1.858760e-15 -30.355801  -0.0
# 482  0.0 -1.858760e-15 -30.355801  -0.0
# 483  0.0 -1.858760e-15 -30.355801  -0.0

# %%
def del_col(df):
    del df["mux"]
    del df["muy"]
    del df["muz"]

    del df["tmux"]
    del df["tmuy"]
    del df["tmuz"]
    return df

# %%
a = del_col(a)
b = del_col(b)

# %%
a['resX'] = a["x"]-a["tx"]
b['resY'] = b["y"]-b["ty"]

# %%
a["spin"] = np.NaN
b["spin"] = np.NaN
a.loc[a.resX > 0, "spin"] = 1
a.loc[a.resX < 0, "spin"] = -1
b.loc[b.resY > 0, "spin"] = 1
b.loc[b.resY < 0, "spin"] = -1

# %%
b.tail(50)
# Out:
#                       x           y    z            tx     ty   tz  \
# frame   id
# 1828300 434  527.994995  656.507996  0.0  5.280000e+02  643.5  0.0
#         435  561.000977  633.018005  0.0  5.610000e+02  643.5  0.0
#         436  594.122009  658.218018  0.0  5.940000e+02  643.5  0.0
#         437  627.015015  635.841003  0.0  6.270000e+02  643.5  0.0
#         438  660.054993  645.452026  0.0  6.600000e+02  643.5  0.0
#         439  693.142029  642.106995  0.0  6.930000e+02  643.5  0.0
#         440    0.002142  691.606995  0.0  1.010330e-15  676.5  0.0
#         441  -15.351013  -1.0
#         442    0.776978   1.0
#         443   15.333984   1.0
#         444   -0.716980  -1.0
#         445   -0.796021  -1.0
#         446   -2.356018  -1.0
#         447   -3.395996  -1.0
#         448    0.036011   1.0
#         449   -5.083008  -1.0
#         450    3.546997   1.0
#         451  -13.013000  -1.0
#         452   12.780029   1.0
#         453    0.101990   1.0
#         454   -2.109985  -1.0
#         455    5.539978   1.0
#         456   -4.017029  -1.0
#         457   13.713989   1.0
#         458   -0.700012  -1.0
#         459    3.684998   1.0
#         460   -3.562988  -1.0
#         461    1.603027   1.0
#         462   -1.000977  -1.0
#         463   -0.982971  -1.0
#         464    4.200012   1.0
#         465   -5.322998  -1.0
#         466    3.083008   1.0
#         467    5.567017   1.0
#         468  -11.135986  -1.0
#         469 -711.481873  -1.0
#         470  -15.088013  -1.0
#         471    3.231995   1.0
#         472   -9.911011  -1.0
#         473 -711.877502  -1.0
#         474   -6.955017  -1.0
#         475 -712.043335  -1.0
#         476   -0.031982  -1.0
#         477  -12.880005  -1.0
#         478    5.143005   1.0
#         479   -1.174011  -1.0
#         480 -710.685547  -1.0
#         481  -10.861023  -1.0
#         482    6.619019   1.0
#         483    0.072998   1.0

# %% [markdown]
# Here I have the spin values of the horizontal traps for all the frames.

# %%
a = a.drop(columns=["x", "tx", "y", "ty", "z", "tz", "resX"])
b = b.drop(columns=["x", "tx", "y", "ty", "z", "tz", "resY"])

# %%
df = a.groupby(['id'])
for i, (n, gr) in enumerate(df):
    if n == 15:
        plt.plot(gr['spin'].values, '-')

# %% [markdown]
# ### Now we see flips of the particles!!!

# %% [markdown]
# I think that the better that I can do if to save the data and start the Spin Overlap Parameter en a new script.

# %%
df_short = filter_RPM_data(a,t)
df_long = filter_RPM_data(b,t)

# %%
df_short.tail(50)
# Out:
#              spin
# frame   id
# 1828300 434  -1.0
#         435   1.0
#         436  -1.0
#         437   1.0
#         438   1.0
#         439  -1.0
#         440  -1.0
#         441   1.0
#         442  -1.0
#         443  -1.0
#         444   1.0
#         445   1.0
#         446   1.0
#         447   1.0
#         448  -1.0
#         449   1.0
#         450  -1.0
#         451   1.0
#         452  -1.0
#         453  -1.0
#         454   1.0
#         455  -1.0
#         456   1.0
#         457  -1.0
#         458   1.0
#         459  -1.0
#         460   1.0
#         461   1.0
#         462   1.0
#         463  -1.0
#         464  -1.0
#         465   1.0
#         466   1.0
#         467  -1.0
#         468   1.0
#         469  -1.0
#         470   1.0
#         471  -1.0
#         472   1.0
#         473  -1.0
#         474   1.0
#         475  -1.0
#         476  -1.0
#         477   1.0
#         478  -1.0
#         479   1.0
#         480  -1.0
#         481   1.0
#         482  -1.0
#         483  -1.0

# %%
save_dir = 'Data_RPM'

# %%
df_short.to_csv(os.path.join(save_dir,'Spins_short_100mT_EXP'+str(k)), sep = '\t')
df_long.to_csv(os.path.join(save_dir,'Spins_long_100mT_EXP'+str(k)), sep = '\t')

# %% [markdown]
# # to do:
#
#     - Find a way to do the trying to solve this paragraph in a loop of all the experiments.
#         (Maybe is not necessary to save all the frames but only the interesting ones)
#     - Save the data.
#     - Compute the Spin Overlap Parameter
