# %% [markdown]
# # Simulation script

# %%
import sys
import os
import shutil
sys.path.insert(0, 'icenumerics/')

import pandas as pd
import numpy as np
import scipy.spatial as spa
import matplotlib.pyplot as plt
import matplotlib as mpl

import icenumerics as ice
from icenumerics.geometry import ordering 
import csv as csv
import time
import string as st
from multiprocessing import Pool

import copy as cp

ureg = ice.ureg

idx = pd.IndexSlice

import tqdm.auto as tqdm

# %reload_ext autoreload
# %autoreload 2
# Out:
# C:\Users\Carolina\Anaconda3\lib\site-packages\tqdm\std.py:648: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
directory = r"."

# %%
e = 1
l = 1

lattice_constant = 33*ureg.um
lattice_size = [l,l]
sp = ice.spins()
sp.create_lattice("square",[l,l],lattice_constant=33*ureg.um, border="periodic")
# sp.order_spins(ordering.random_ordering)

sp.display()

# %% [markdown]
# New parameters in order to try to recover the full degeneracy.

# %%
particle1 = ice.particle(radius = 1*ureg.um,
         susceptibility = 0.5,
         diffusion = 0.2188*ureg.um**2/ureg.s,
         temperature = 300*ureg.K,
         density = 1000*ureg.kg/ureg.m**3)

particle2 = ice.particle(radius = 1*ureg.um,
         susceptibility = 0.0675151,
         diffusion = 0.2188*ureg.um**2/ureg.s,
         temperature = 300*ureg.K,
         density = 1000*ureg.kg/ureg.m**3)

trap_short = ice.trap(trap_sep = 23*ureg.um,
               height = 10*ureg.pN*ureg.nm,
               stiffness = 6e-4*ureg.pN/ureg.nm)

trap_long = ice.trap(trap_sep = 30.3558*ureg.um,
               height = 10*ureg.pN*ureg.nm,
               stiffness = 6e-4*ureg.pN/ureg.nm)


traps = []
particles = []

for s in sp:

    if s.direction[1] == 0:
        # Horizontal traps
        traps.append(trap_short) 
        particles.append(particle1)
        pass

    else: 
        # Vertical traps
        traps.append(trap_long) 
        particles.append(particle2)

# %% [markdown]
# First we will reset the 0 values

# %%
# Loop to change the default value of s.center from e-19 to 0.
## ONLY IF PERIODIC BORDER ARE USED ##

for s in sp:
#     print(s.center[0])
    if s.center[0] < 16*ureg.um:
        s.center[0] = 0.*ureg.um

# %%
lattice = 33

# %% [markdown]
# First we will change the horizontal traps

# %%
for s in sp:
    
    for i in range(0,l):
        # For the traps in Even positions.
        if i % 2 == 0:
            for j in range(0,l):
                if j % 2 == 0:
                    if all(s.center == [lattice/2+i*lattice,j*lattice,0.]*ureg.um) :
                        s.direction =[-33,0.,0.]*ureg.um
        
        #For traps in Odd positions.
        else:
            for j in range(0,l):
                if j % 2 == 0:
                    pass
                else:
                    if all(s.center == [lattice/2+i*lattice,j*lattice,0.]*ureg.um) :
                        s.direction =[-33,0.,0.]*ureg.um

# %% [markdown]
# And now the vertical ones.

# %%
for s in sp:
    
    for i in range(0,l):
        if i % 2 == 0:
            for j in range(0,l):
                if j % 2 == 0:
                    pass
                else:
                    if all(s.center == [i*lattice,lattice/2+j*lattice,0.]*ureg.um) :
                        s.direction = [0.,-33,0.]*ureg.um
        else:
            for j in range(0,l):
                if j % 2 == 0:
                    if all(s.center == [i*lattice,lattice/2+j*lattice,0.]*ureg.um) :
                        s.direction = [0.,-33,0.]*ureg.um

# %%
sp.display()

# %%
col = ice.colloidal_ice(sp, particles, traps , height_spread = 0 , susceptibility_spread = 0)
col.display()

# %%
col.calculate_energy(B = [0,0,30]*ureg.mT)
# Out:
# 1.023460821124548 <Unit('nanometer * piconewton')>

# %%
col.region[:,:2]=(np.array([np.array([0,0]),lattice_size])-0.1)*(lattice_constant)
col.region[:,2] = np.array([-.11,.11])*ureg.um

col.display()

# %%
world = ice.world(
    field = 70*ureg.mT,
    temperature = 300*ureg.K,
    dipole_cutoff = 200*ureg.um,
    boundaries = ["p", "p", "p"])

total_time = 100*ureg.s
col.simulation(world,
             name = "FullyDegeneracy_Type3_l%u_exp%u"%(l,e),
             include_timestamp = False,
             targetdir = directory,
             framerate = 5*ureg.Hz,
             timestep = 10*ureg.ms,
             run_time = total_time,
             output = ["x","y","z","mux","muy","muz"])


# col.sim.field.fieldz = 50*ureg.mT   
col.sim.field.fieldz = "v_Bmag"
col.run_simulation()

# %%
col.load_simulation()
col.display()

# %%
col.trj.tail()
# Out:
#           type          x          y    z           mux        muy       muz  \
# frame id
# 498   4      2   0.000000  16.500000  0.0  1.858760e-15  30.355801  0.000000
# 499   1      1   4.780860   0.065441  0.0  0.000000e+00   0.000000  0.000053
#       2      1  -0.172569  -1.312670  0.0  0.000000e+00   0.000000  0.000053
#       3      2  16.500000   0.000000  0.0 -3.035580e+01   0.000000  0.000000
#       4      2   0.000000  16.500000  0.0  1.858760e-15  30.355801  0.000000
#
#              t
# frame id
# 498   4   99.6
# 499   1   99.8
#       2   99.8
#       3   99.8
#       4   99.8

# %%
499/99.8*20
# Out:
# 100.0

# %% [markdown]
# # Visual pre analysis of the Simulation

# %%
f, axes = plt.subplots(3,2,figsize = (20,20))
ax1, ax2, ax3, ax4, ax5,ax6 = axes.flatten()

col.set_state_from_frame(50)
ax1.set_title('0mT')
col.display(ax1)
col.set_state_from_frame(100)
col.calculate_energy(B = [0,0,50]*ureg.mT)
ax2.set_title('frame 100')
col.display(ax2)
col.set_state_from_frame(200)
col.calculate_energy(B = [0,0,50]*ureg.mT)
ax3.set_title('frame 600')
col.display(ax3)
col.set_state_from_frame(300)
col.calculate_energy(B = [0,0,50]*ureg.mT)
ax4.set_title('frame 700')
col.display(ax4)
col.set_state_from_frame(400)
col.calculate_energy(B = [0,0,50]*ureg.mT)
ax5.set_title('frame 800')
col.display(ax5)
col.set_state_from_frame(499)
col.calculate_energy(B = [0,0,50]*ureg.mT)
ax6.set_title('50mT')
col.display(ax6)

# %% [markdown]
# # Following the Energy value of the whole system

# %%
col.set_state_from_frame(100)
col.calculate_energy(B = [0,0,70]*ureg.mT).magnitude
# Out:
# 1334.4621498368597

# %%
E = []
t = []
for i in range(0,499):
    col.set_state_from_frame(i)
    E.append(col.calculate_energy(B = [0,0,70]*ureg.mT).magnitude)
    # 5 fr/s
    t.append(i/5)

# %% [markdown]
# The units of the energy are nanometer * piconewton

# %%
mpl.rc('text', usetex=False)
mpl.rcParams['figure.dpi'] = 500

mpl.rcParams['font.family'] = 'serif'

# ax1.tick_params(axis='y', labelsize=30)    
  

# ax3.tick_params(axis='x', labelsize=30)

# %%
t[100],E[100], E[0]
# Out:
# (20.0, 1334.4621498368597, 1328.5832477060585)

# %%
plt.plot(t,E)
plt.xlabel('Time (s)', size = 20)
plt.ylabel('Energy (nm·pN)', size = 20)
plt.tight_layout()
# plt.savefig('Evst_type3conf')
